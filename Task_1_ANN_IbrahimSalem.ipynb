# %% [markdown]
# # Exam on Artificial Neural Networks (ANN)
#
# Welcome the Artificial Neural Networks (ANN) practical exam. In this exam, you will work on a classification task to predict the outcome of incidents involving buses. You are provided with a dataset that records breakdowns and delays in bus operations. Your task is to build, train, and evaluate an ANN model.
#
# ---
#
# ## Dataset Overview
#
# ### **Dataset:**
# * Just run the command under the `Load Data` section to get the data downloaded and unzipped or you can access it [here](https://drive.google.com/file/d/1Flvj3qDkV2rPw7GGi5zOR-WGJgEBtRk-/view?usp=sharing)
#
# ### **Dataset Name:** Bus Breakdown and Delays
#
# ### **Description:**
# The dataset contains records of incidents involving buses that were either running late or experienced a breakdown. Your task is to predict whether the bus was delayed or had a breakdown based on the features provided.
#
# ### **Features:**
# The dataset contains the following columns:
#
# - `School_Year`
# - `Busbreakdown_ID`
# - `Run_Type`
# - `Bus_No`
# - `Route_Number`
# - `Reason`
# - `Schools_Serviced`
# - `Occurred_On`
# - `Created_On`
# - `Boro`
# - `Bus_Company_Name`
# - `How_Long_Delayed`
# - `Number_Of_Students_On_The_Bus`
# - `Has_Contractor_Notified_Schools`
# - `Has_Contractor_Notified_Parents`
# - `Have_You_Alerted_OPT`
# - `Informed_On`
# - `Incident_Number`
# - `Last_Updated_On`
# - `Breakdown_or_Running_Late` (Target Column)
# - `School_Age_or_PreK`

# %% [markdown]
# ## Load Data

# %%
#https://drive.google.com/file/d/1Flvj3qDkV2rPw7GGi5zOR-WGJgEBtRk-/view?usp=sharing
# !pip install gdown
# !gdown --id 1Flvj3qDkV2rPw7GGi5zOR-WGJgEBtRk-
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Failed to retrieve file url:
#
# 	Too many users have viewed or downloaded this file recently. Please
# 	try accessing the file again later. If the file you are trying to
# 	access is particularly large or is shared with many people, it may
# 	take up to 24 hours to be able to view or download the file. If you
# 	still can't access a file after 24 hours, contact your domain
# 	administrator.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1Flvj3qDkV2rPw7GGi5zOR-WGJgEBtRk-
#
# but Gdown can't. Please check connections and permissions.

# %% [markdown]
# ## Importing Libraries

# %% [markdown]
# GOAL: predict bus is o

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/content/Bus_Breakdown_and_Delays.csv')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# This could include:
# * **Inspect the dataset**
#
# * **Dataset structure**
#
# * **Summary statistics**
#
# * **Check for missing values**
#
# * **Distribution of features**
#
# * **Categorical feature analysis**
#
# * **Correlation matrix**
#
# * **Outlier detection**
#
# And add more as needed!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147972 entries, 0 to 147971
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   School_Year                      147972 non-null  object
#  1   Busbreakdown_ID                  147972 non-null  int64
#  2   Run_Type                         147883 non-null  object
#  3   Bus_No                           147972 non-null  object
#  4   Route_Number                     147884 non-null  object
#  5   Reason                           147870 non-null  object
#  6   Schools_Serviced                 147972 non-null  object
#  7   Occurred_On                      147972 non-null  object
#  8   Created_On                       147972 non-null  object
#  9   Boro                             141654 non-null  object
#  10  Bus_Company_Name                 147972 non-null  object
# ...

# %%
df.head()
# Out:
#   School_Year  Busbreakdown_ID  Run_Type Bus_No Route_Number         Reason  \
# 0   2015-2016          1224901  Pre-K/EI    811            1          Other
# 1   2015-2016          1225098  Pre-K/EI   9302            1  Heavy Traffic
# 2   2015-2016          1215800  Pre-K/EI    358            2  Heavy Traffic
# 3   2015-2016          1215511  Pre-K/EI    331            2          Other
# 4   2015-2016          1215828  Pre-K/EI    332            2          Other
#
#   Schools_Serviced             Occurred_On              Created_On   Boro  \
# 0             C353  10/26/2015 08:30:00 AM  10/26/2015 08:40:00 AM  Bronx
# 1             C814  10/27/2015 07:10:00 AM  10/27/2015 07:11:00 AM  Bronx
# 2             C195  09/18/2015 07:36:00 AM  09/18/2015 07:38:00 AM  Bronx
# 3             C178  09/17/2015 08:08:00 AM  09/17/2015 08:12:00 AM  Bronx
# 4             S176  09/18/2015 07:39:00 AM  09/18/2015 07:45:00 AM  Bronx
#
#    ... How_Long_Delayed Number_Of_Students_On_The_Bus  \
# ...

# %%
df.sample(10)
# Out:
#        School_Year  Busbreakdown_ID           Run_Type Bus_No Route_Number  \
# 71232    2016-2017          1291912  Special Ed AM Run  10456         X080
# 62635    2016-2017          1283385  Special Ed AM Run   1011         M270
# 112456   2016-2017          1333698  Special Ed AM Run   2614         Q155
# 109127   2016-2017          1330399  General Ed AM Run   2367        Q3095
# 2548     2015-2016          1216762  Special Ed PM Run    822         N803
# 75288    2016-2017          1296011  Special Ed AM Run  4452D         L627
# 39629    2015-2016          1259849  Special Ed AM Run   4555         L680
# 37408    2015-2016          1257534  Special Ed AM Run   2508         K282
# 28620    2015-2016          1248565  Special Ed AM Run   1401         K615
# 82504    2016-2017          1303264           Pre-K/EI    118            6
#
#                     Reason Schools_Serviced             Occurred_On  \
# 71232        Heavy Traffic            07520  10/13/2016 07:25:00 AM
# ...

# %%
df.tail()
# Out:
#        School_Year  Busbreakdown_ID             Run_Type  Bus_No Route_Number  \
# 147967   2016-2017          1338452             Pre-K/EI    9345            2
# 147968   2016-2017          1341521             Pre-K/EI    0001            5
# 147969   2016-2017          1353044    Special Ed PM Run  GC0112         X928
# 147970   2016-2017          1353045    Special Ed PM Run   5525D         Q920
# 147971   2016-2017          1353046  Project Read PM Run    2530         K617
#
#                Reason Schools_Serviced             Occurred_On  \
# 147967  Heavy Traffic             C530  04/05/2017 08:00:00 AM
# 147968  Heavy Traffic             C579  04/24/2017 07:42:00 AM
# 147969  Heavy Traffic            09003  05/25/2017 04:22:00 PM
# 147970    Won`t Start            24457  05/25/2017 04:27:00 PM
# 147971          Other            21436  05/25/2017 04:36:00 PM
#
#                     Created_On      Boro  ... How_Long_Delayed  \
# ...

# %%
df['Breakdown_or_Running_Late'].value_counts()
# Out:
# Breakdown_or_Running_Late
# Running Late    130857
# Breakdown        17115
# Name: count, dtype: int64

# %%
df['Boro'].value_counts()
# Out:
# Boro
# Bronx              40995
# Brooklyn           35632
# Manhattan          28675
# Queens             21169
# Staten Island       6923
# Westchester         4535
# Nassau County       1970
# New Jersey           887
# Rockland County      491
# All Boroughs         275
# Connecticut          102
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# School_Year                             0
# Busbreakdown_ID                         0
# Run_Type                               89
# Bus_No                                  0
# Route_Number                           88
# Reason                                102
# Schools_Serviced                        0
# Occurred_On                             0
# Created_On                              0
# Boro                                 6318
# Bus_Company_Name                        0
# How_Long_Delayed                    21630
# Number_Of_Students_On_The_Bus           0
# Has_Contractor_Notified_Schools         0
# Has_Contractor_Notified_Parents         0
# Have_You_Alerted_OPT                    0
# Informed_On                             0
# Incident_Number                    142340
# Last_Updated_On                         0
# Breakdown_or_Running_Late               0
# School_Age_or_PreK                      0
# dtype: int64

# %%
df['Route_Number'].value_counts()
# Out:
# Route_Number
# 1         2569
# 2         2217
# 3         1904
# 5         1740
# 4         1093
#           ...
# 26Q7MD       1
# M688         1
# JC-1         1
# W656         1
# 1409B        1
# Name: count, Length: 11283, dtype: int64

# %%
df['Run_Type'].value_counts()
# Out:
# Run_Type
# Special Ed AM Run          85990
# Pre-K/EI                   20951
# Special Ed PM Run          17672
# General Ed AM Run          17182
# General Ed PM Run           4541
# Special Ed Field Trip        628
# General Ed Field Trip        570
# Project Read PM Run          300
# Project Read AM Run           47
# Project Read Field Trip        2
# Name: count, dtype: int64

# %%
df['Bus_Company_Name'].value_counts()
# Out:
# Bus_Company_Name
# G.V.C., LTD.                       14198
# RELIANT TRANS, INC. (B232          13741
# PIONEER TRANSPORTATION CO          11990
# LEESEL TRANSP CORP (B2192          11553
# NEW DAWN TRANSIT, LLC (B2          10533
#                                    ...
# EMPIRE CHARTER SERVICE INC             2
# FIRST STEPS TRANSP INC. (B2192)        1
# alina                                  1
# phillip bus service                    1
# FORTUNA BUS COMPANY                    1
# Name: count, Length: 91, dtype: int64

# %%
df['Reason'].value_counts()
# Out:
# Reason
# Heavy Traffic                  87426
# Other                          21666
# Mechanical Problem             13908
# Won`t Start                     7277
# Flat Tire                       4585
# Weather Conditions              4527
# Late return from Field Trip     3464
# Problem Run                     2204
# Delayed by School               1446
# Accident                        1367
# Name: count, dtype: int64

# %%
grop=df.groupby(['Reason','Breakdown_or_Running_Late']).sum()
grop
# Out:
#                                                                                              School_Year  \
# Reason                      Breakdown_or_Running_Late
# Accident                    Breakdown                  2015-20162015-20162015-20162015-20162015-20162...
#                             Running Late               2015-20162015-20162015-20162015-20162015-20162...
# Delayed by School           Breakdown                                                 2015-20162016-2017
#                             Running Late               2015-20162015-20162015-20162015-20162015-20162...
# Flat Tire                   Breakdown                  2015-20162015-20162015-20162015-20162015-20162...
#                             Running Late               2015-20162015-20162015-20162015-20162015-20162...
# Heavy Traffic               Breakdown                  2015-20162015-20162015-20162015-20162015-20162...
# ...

# %% [markdown]
# ## Dropping columns:
#
# How_Long_Delayed   **Justification**: every time there is value on it means that the class is 'Running late'
#
#
# Incident_Number **Justification**: lot of nulls and useless and multpule busess canot have same incident no
#
# Route_Number **Justification**: Useless
#
#
# Bus_Company_Name    **Justification**: Useless, many names on it
#
# Bus_no
#
# School_Year
#
# Busbreakdown_ID
#
# run type  **Justification**: complex details
#
# Schools_Serviced **Justification**: Useless

# %%
df= df.drop(columns=['How_Long_Delayed','Incident_Number','Route_Number'])

# %%
df= df.drop(columns=['Bus_Company_Name','Bus_No'])

# %%
df= df.drop(columns=['School_Year','Busbreakdown_ID'])

# %%
df= df.drop(columns=['Schools_Serviced','Run_Type'])

# %% [markdown]
# # dropping nulls because they dont exceed 100 for two columns

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Reason                             0
# Occurred_On                        0
# Created_On                         0
# Boro                               0
# Number_Of_Students_On_The_Bus      0
# Has_Contractor_Notified_Schools    0
# Has_Contractor_Notified_Parents    0
# Have_You_Alerted_OPT               0
# Informed_On                        0
# Last_Updated_On                    0
# Breakdown_or_Running_Late          0
# School_Age_or_PreK                 0
# dtype: int64

# %%
dfNodates=df.drop(columns=['Occurred_On','Created_On','Last_Updated_On','Informed_On'])
dfNodates
# Out:
#                Reason      Boro  Number_Of_Students_On_The_Bus  \
# 0               Other     Bronx                              5
# 1       Heavy Traffic     Bronx                              3
# 2       Heavy Traffic     Bronx                             12
# 3               Other     Bronx                             11
# 4               Other     Bronx                             12
# ...               ...       ...                            ...
# 147967  Heavy Traffic     Bronx                              7
# 147968  Heavy Traffic     Bronx                              0
# 147969  Heavy Traffic     Bronx                              0
# 147970    Won`t Start    Queens                              0
# 147971          Other  Brooklyn                              7
#
#        Has_Contractor_Notified_Schools Has_Contractor_Notified_Parents  \
# 0                                  Yes                             Yes
# ...

# %% [markdown]
# ## Data Preprocessing
# This could include:
#
# * **Handle Missing Values**
#     * Impute missing values or drop them.
#
# * **Encode Categorical Variables**
#     * One-hot encoding
#     * Label encoding
#
# * **Scale and Normalize Data**
#     * Standardization (Z-score)
#     * Min-Max scaling
#
# * **Feature Engineering**
#     * Create new features
#     * Feature selection
#
# * **Handle Imbalanced Data**
#     * Oversampling
#     * Undersampling
#
# * **Handle Outliers**
#     * Remove outliers
#     * Transform outliers
#
# * **Remove Duplicates**
#     * Remove redundant or duplicate data
#
#
# And add more as needed!
#
# Please treat these as suggestions. Feel free to use your judgment for the rest.

# %% [markdown]
# ### Handling missing value is done up in EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 141554 entries, 0 to 147971
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Reason                           141554 non-null  object
#  1   Occurred_On                      141554 non-null  object
#  2   Created_On                       141554 non-null  object
#  3   Boro                             141554 non-null  object
#  4   Number_Of_Students_On_The_Bus    141554 non-null  int64
#  5   Has_Contractor_Notified_Schools  141554 non-null  object
#  6   Has_Contractor_Notified_Parents  141554 non-null  object
#  7   Have_You_Alerted_OPT             141554 non-null  object
#  8   Informed_On                      141554 non-null  object
#  9   Last_Updated_On                  141554 non-null  object
#  10  Breakdown_or_Running_Late        141554 non-null  object
# ...

# %%
labelE = LabelEncoder()
dfNodates['Boro'] = labelE.fit_transform(dfNodates['Boro'])
dfNodates['Reason'] = labelE.fit_transform(dfNodates['Reason'])

dfNodates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 141554 entries, 0 to 147971
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Reason                           141554 non-null  int64
#  1   Boro                             141554 non-null  int64
#  2   Number_Of_Students_On_The_Bus    141554 non-null  int64
#  3   Has_Contractor_Notified_Schools  141554 non-null  object
#  4   Has_Contractor_Notified_Parents  141554 non-null  object
#  5   Have_You_Alerted_OPT             141554 non-null  object
#  6   Breakdown_or_Running_Late        141554 non-null  object
#  7   School_Age_or_PreK               141554 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 9.7+ MB

# %% [markdown]
# One Hot Encoder for booleans and schol age pr perk

# %%
dfNodates = pd.get_dummies(dfNodates, columns=['Has_Contractor_Notified_Schools', 'Has_Contractor_Notified_Parents',
                                               'Have_You_Alerted_OPT','School_Age_or_PreK'])
dfNodates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 141554 entries, 0 to 147971
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Reason                               141554 non-null  int64
#  1   Boro                                 141554 non-null  int64
#  2   Number_Of_Students_On_The_Bus        141554 non-null  int64
#  3   Breakdown_or_Running_Late            141554 non-null  object
#  4   Has_Contractor_Notified_Schools_No   141554 non-null  bool
#  5   Has_Contractor_Notified_Schools_Yes  141554 non-null  bool
#  6   Has_Contractor_Notified_Parents_No   141554 non-null  bool
#  7   Has_Contractor_Notified_Parents_Yes  141554 non-null  bool
#  8   Have_You_Alerted_OPT_No              141554 non-null  bool
#  9   Have_You_Alerted_OPT_Yes             141554 non-null  bool
#  10  School_Age_or_PreK_Pre-K             141554 non-null  bool
# ...

# %%
dfNodates['Breakdown_or_Running_Late'] = labelE.fit_transform(dfNodates['Breakdown_or_Running_Late'])
dfNodates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 141554 entries, 0 to 147971
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Reason                               141554 non-null  int64
#  1   Boro                                 141554 non-null  int64
#  2   Number_Of_Students_On_The_Bus        141554 non-null  int64
#  3   Breakdown_or_Running_Late            141554 non-null  int64
#  4   Has_Contractor_Notified_Schools_No   141554 non-null  bool
#  5   Has_Contractor_Notified_Schools_Yes  141554 non-null  bool
#  6   Has_Contractor_Notified_Parents_No   141554 non-null  bool
#  7   Has_Contractor_Notified_Parents_Yes  141554 non-null  bool
#  8   Have_You_Alerted_OPT_No              141554 non-null  bool
#  9   Have_You_Alerted_OPT_Yes             141554 non-null  bool
#  10  School_Age_or_PreK_Pre-K             141554 non-null  bool
# ...

# %% [markdown]
# ## Split the Dataset
# Next, split the dataset into training, validation, and testing sets.

# %%
X=dfNodates.drop(columns=['Breakdown_or_Running_Late'])
y=dfNodates['Breakdown_or_Running_Late']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %% [markdown]
# ## Building the ANN Model
# In this section, define the architecture of the ANN by specifying the number of layers, neurons, and activation functions.

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Compile the Model
# Compile the ANN model by defining the optimizer, loss function, and evaluation metrics.

# %%
# compile
model.compile(
optimizer='adam',
loss='binary_crossentropy',
metrics=['accuracy']
)

# %% [markdown]
# ## Training the Model
# Train the ANN model using the training data.

# %%
history=model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=32,
    epochs=20
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-ff3ce024a0fe> in <cell line: 1>()
# ----> 1 history=model.fit(
#       2     X_train,
#       3     y_train,
#       4     validation_split=0.2,
#       5     batch_size=32,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     106       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107   ctx.ensure_initialized()
# ...

# %% [markdown]
# ## Evaluate the Model
# Evaluate the performance of the model on the test set.

# %%
lossv,val_acc=model.evaluate(val_ds)
print("Validation Accuracy:")
print(val_acc)

# %%
losst,test_acc=model.evaluate(test_ds)
print("Test Accuracy:")
print(test_acc)

# %% [markdown]
# ## Make Predictions
# Use the trained model to make predictions on new or unseen data.

# %% [markdown]
# ## Model Performance Visualization
# Visualize the performance metrics such as accuracy and loss over the epochs.

# %% [markdown]
# ## Save the Model
# Save the trained model for submission.

# %% [markdown]
# ## Project Questions:
#
# 1. **Data Preprocessing**: Explain why you chose your specific data preprocessing techniques (e.g., normalization, encoding). How did these techniques help prepare the data for training the model?
# 2. **Model Architecture**: Describe the reasoning behind your model’s architecture (e.g., the number of layers, type of layers, number of neurons, and activation functions). Why did you believe this architecture was appropriate for the problem at hand?
# 3. **Training Process**: Discuss why you chose your batch size, number of epochs, and optimizer. How did these choices affect the training process? Did you experiment with different values, and what were the outcomes?
# 4. **Loss Function and Metrics**: Why did you choose the specific loss function and evaluation metrics? How do they align with the objective of the task (e.g., regression vs classification)?
# 5. **Regularization Techniques**: If you used regularization techniques such as dropout or weight decay, explain why you implemented them and how they influenced the model's performance.
# 6. **Model Evaluation**: Justify your approach to evaluating the model. Why did you choose the specific performance metrics, and how do they reflect the model's success in solving the task?
# 7. **Model Tuning (If Done)**: Describe any tuning you performed (e.g., hyperparameter tuning) and why you felt it was necessary. How did these adjustments improve model performance?
# 8. **Overfitting and Underfitting**: Analyze whether the model encountered any overfitting or underfitting during training. What strategies could you implement to mitigate these issues?

# %% [markdown]
# ### Answer Here:
